# %%
import re
import warnings
import pandas as pd
# from modules.transform_mod import process_raw_data

warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def normalize_strings(df, transformations):
    """
    Function to normalize strings in specified columns of a DataFrame.
    
    Parameters:
        df (pandas.DataFrame): DataFrame containing the columns to be normalized.
        transformations (dict): Dictionary where keys are column names and values are lists of regular expressions to apply to each respective column.
    
    Returns:
        pandas.DataFrame: DataFrame with normalized strings in specified columns.
    """
    # Apply transformations to each specified column
    for column, regex_list in transformations.items():
        if column in df.columns:
            for regex in regex_list:
                df[column] = df[column].str.replace(regex[0], regex[1], regex=True)
    
    return df

# %% [markdown]
# #### Transforming column string values
# The following dataframe columns will be transformed using regular expressions.
#
# * Strip leading and trailing whitespace: (r'^\s+|\s+$', '')
#
# * Replace any sequence of whitespace characters with a single space: (r'\s+', ' ')
# * Remove spaces between numbers and 'mg': (r'(\d+(\.\d+)?)\s*mg', r'\1mg)
# * Convert all letters to lowercase: (r'([a-zA-Z]+)', lambda x: x.group(0).lower())
# * Remove whitespace around slashes: (r'\s*([/])\s*', r'\1')
# * Remove whitespace around hyphens: (r'\s*-\s*', '-')
# * Replace '&' with 'and': (r'&', 'and')
# * Remove '\r\n': (r'\r\n', '')
# * Replace '{' with '(': (r'\{', '(')
# * Replace '}' with ')': (r'\}', ')')
# * Replace any instance of '{}' with '()': (r'\{.*?\}', '()')

# %%
transformations_1 = {
    'drug_name': [
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
    ]
}

transformations_2 = {
    'generic_name_1': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_2': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_3': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_4': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_5': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
}

transformations_3 = {
    'use_case_1': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
    ],
    'use_case_2': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
    ],
}

transformations_4 = {
    'chemical_class': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'&', 'and'),
        (r'\r\n', ''),
        (r'\{', '('),
        (r'\}', ')'),
        (r'\{.*?\}', '()'),
        (r'\s*-\s*', '-'),
        (r'\s*([/])\s*', r'\1'),
    ],
    'therapeutic_class': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\r\n', ''),
        (r'\s*-\s*', '-'),
        (r'\s*([/])\s*', r'\1'),
    ],
    'action_class': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'&', 'and'),
        (r'\r\n', ''),
        (r'\{', '('),
        (r'\}', ')'),
        (r'\{.*?\}', '()'),
        (r'\s*-\s*', '-'),
        (r'\s*([/])\s*', r'\1'),
    ]
}

transformations_5 = {
    'use_case_1': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'&', 'and'),
        (r'\r\n', ''),
        (r'\{', '('),
        (r'\}', ')'),
        (r'\{.*?\}', '()'),
        (r'\s*-\s*', '-'),
        (r'\s*([/])\s*', r'\1'),
    ],
    'generic_name_1': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_2': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_3': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_4': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'generic_name_5': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'(\d+(\.\d+)?)\s*mg', r'\1mg'),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
    ],
    'therapeutic_class': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\r\n', ''),
        (r'\s*-\s*', '-'),
        (r'\s*([/])\s*', r'\1'),
    ],
}

transformations_6 = {
    'side_effect_1': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
        (r'&', 'and'),
        (r'\r\n', ''),
    ],
    'side_effect_2': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
        (r'&', 'and'),
        (r'\r\n', ''),
    ],
    'side_effect_3': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
        (r'&', 'and'),
        (r'\r\n', ''),
    ],
    'side_effect_4': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
        (r'&', 'and'),
        (r'\r\n', ''),
    ],
    'side_effect_5': [
        (r'([a-zA-Z]+)', lambda x: x.group(0).lower()),
        (r'^\s+|\s+$', ''),
        (r'\s+', ' '),
        (r'\s*([/])\s*', r'\1'),
        (r'\s*-\s*', '-'),
        (r'&', 'and'),
        (r'\r\n', ''),
    ],
}

# %% [markdown]
# #### Preprocess Source Data

# %%
file_path = '../data/raw/medicine_dataset.csv'
file_name = 'Med_data'
interm_folder = '../data/interm'
# process_raw_data(file_path, interm_folder, file_name)

# %% [markdown]
# #### Apply unique transformations to the preprocessed data

# %%
# Load dataframes to clean
Drugs = pd.read_csv('../data/interm/Med_data_1_drugs.csv')
Generic_Names = pd.read_csv('../data/interm/Med_data_2_generic_names.csv')
Side_Effects = pd.read_csv('../data/interm/Med_data_3_side_effects.csv')
Use_Case = pd.read_csv('../data/interm/Med_data_4_use_case.csv')
Drug_Class = pd.read_csv('../data/interm/Med_data_5_drug_class.csv')
Drug_State = pd.read_csv('../data/interm/Med_data_6_drug_state.csv')

# %% [markdown]
# #### Transform Drugs

# %%
# Apply the normalization function to the dataframe column
Drugs_normalized = normalize_strings(Drugs, transformations_1)

# %%
Drugs_normalized.head(45)
# Out:
#     drug_id                               drug_name habit_forming
# 0         1                augmentin 625 duo tablet            No
# 1         2                     azithral 500 tablet            No
# 2         3                        ascoril ls syrup            No
# 3         4                    allegra 120mg tablet            No
# 4         5                          avil 25 tablet            No
# 5         6                        allegra-m tablet            No
# 6         7                    amoxyclav 625 tablet            No
# 7         8                         azee 500 tablet            No
# 8         9                      atarax 25mg tablet            No
# 9        10         ascoril d plus syrup sugar free            No
# 10       11                       aciloc 150 tablet            No
# 11       12                              alex syrup            No
# 12       13                           anovate cream            No
# 13       14           augmentin duo oral suspension            No
# 14       15                        ambrodil-s syrup            No
# 15       16                          arkamin tablet            No
# 16       17                          avomine tablet            No
# 17       18           asthakind-dx syrup sugar free            No
# 18       19                    allegra 180mg tablet            No
# 19       20                albendazole 400mg tablet            No
# 20       21                          asthalin syrup            No
# 21       22                      alprax 0.25 tablet           Yes
# 22       23                     altraday capsule sr            No
# 23       24                       ativan 2mg tablet           Yes
# 24       25                 ascoril ls junior syrup            No
# 25       26                 asthalin 100mcg inhaler            No
# 26       27                       almox 500 capsule            No
# 27       28                      atarax 10mg tablet            No
# 28       29                     aciloc rd 20 tablet            No
# 29       30                        aldactone tablet            No
# 30       31  allegra suspension raspberry & vanilla            No
# 31       32                            atarax syrup            No
# 32       33                      amlokind-at tablet            No
# 33       34                       axcer 90mg tablet            No
# 34       35                       ativan 1mg tablet           Yes
# 35       36                   alkasol oral solution            No
# 36       37          aldigesic p 100mg/325mg tablet            No
# 37       38                    alfoo 10mg tablet pr            No
# 38       39                     alprax 0.5mg tablet           Yes
# 39       40                  arachitol 6l injection            No
# 40       41             anafortan 25mg/300mg tablet            No
# 41       42                       alex junior syrup            No
# 42       43                     azithral 200 liquid            No
# 43       44                     ab phylline capsule            No
# 44       45                    althrocin 500 tablet            No

# %% [markdown]
# #### Transform Generic Names
#
# - One thing that could be done to further clean the Generic Names is to inlclude 'mg' after any string that has a number before it.
#
# - Another way would be to compare the string with the one in the column next to it, if 'mg' is present in the column over, then it is transformed.

# %%
Generic_Names_normalized = normalize_strings(Generic_Names, transformations_2)

# %%
# Drop rows where Drug_ID has a value, but all other columns are NaN
Generic_Names_normalized = Generic_Names_normalized.dropna(
    subset=[
        "generic_name_1",
        "generic_name_2",
        "generic_name_3",
        "generic_name_4",
        "generic_name_5",
    ],
    how="all",
)

Generic_Names_cleaned = Generic_Names_normalized.reset_index(drop=True)

# %%
Generic_Names_cleaned.head(40)
# Out:
#     drug_id                      generic_name_1               generic_name_2  \
# 0         1        penciclav 500mg/125mg tablet       moxikind-cv 625 tablet
# 1         2             zithrocare 500mg tablet              azax 500 tablet
# 2         3                     solvin ls syrup            ambrodil-lx syrup
# 3         4                        lcfex tablet          etofex 120mg tablet
# 4         5                  eralet 25mg tablet                          NaN
# 5         6                  emlukast-fx tablet            lcfex-mont tablet
# 6         7        penciclav 500mg/125mg tablet       moxikind-cv 625 tablet
# 7         8             zithrocare 500mg tablet              azax 500 tablet
# 8         9                 hd zine 25mg tablet              hyzox 25 tablet
# 9        10                     arnikof d syrup             cofsolve-d syrup
# 10       11                  zinemac 150 tablet         monoloc 150mg tablet
# 11       12                  alkof junior syrup            respicure-d syrup
# 12       13                       pilo go cream              pileclear cream
# 13       14            goldclav oral suspension           moxiclip dry syrup
# 14       16              albamine 100mcg tablet          arkapres 100 tablet
# 15       17                    propazine tablet          progene 25mg tablet
# 16       18    wytuss-dmr syrup mint sugar free  dcrocof-dx syrup sugar free
# 17       19                    lcfex 180 tablet         fexofen 180mg tablet
# 18       20                 olworm 400mg tablet                zeebee tablet
# 19       21              brethmol 2mg/5ml syrup            salvent 2mg syrup
# 20       22                alltop 0.25mg tablet      alprasafe 0.25mg tablet
# 21       23        krd ar 200mg/20mg capsule sr           rient-a capsule sr
# 22       24                   zepnap 2mg tablet             lorel 2mg tablet
# 23       25            bronkolyte levo pd syrup               nakuf ls syrup
# 24       26             rheolin 100 mcg inhaler   ventorlin inhaler cfc free
# 25       27              tormoxin 500mg capsule           cipmox 500 capsule
# 26       28                   evall 10mg tablet            hydil 10mg tablet
# 27       29             zydero 10mg/20mg tablet      try dm 10mg/20mg tablet
# 28       30                aldobloc 25mg tablet           spirix 25mg tablet
# 29       31        fexovis 30mg oral suspension      fextric oral suspension
# 30       32                    hydil 10mg syrup               pru 10mg syrup
# 31       33                  biopress am tablet             lupidip-a tablet
# 32       34                   tikacad 90 tablet               brigrel tablet
# 33       35                   lzepam 1mg tablet             lopam 1mg tablet
# 34       36                uridol oral solution                          NaN
# 35       37      dolostat pc 100mg/325mg tablet    acimol 100mg/325mg tablet
# 36       38  davaindia alfuzosin 10mg tablet pr       alfucal 10mg tablet pr
# 37       39              alprasafe 0.5mg tablet      alparazole 0.5mg tablet
# 38       40         sychitol 600000iu injection    devita 600000iu injection
# 39       41       carespas cp 25mg/300mg tablet    camyfyl 25mg/300mg tablet
#
#                    generic_name_3                     generic_name_4  \
# 0         moxiforce-cv 625 tablet                 fightox 625 tablet
# 1                 zady 500 tablet              cazithro 500mg tablet
# 2               zerotuss xp syrup                     capex ls syrup
# 3            nexofex 120mg tablet                fexise 120mg tablet
# 4                             NaN                                NaN
# 5         fixar 10mg/120mg tablet                 histakind-m tablet
# 6         moxiforce-cv 625 tablet                 fightox 625 tablet
# 7                 zady 500 tablet              cazithro 500mg tablet
# 8               hizet 25mg tablet                  hydil 25mg tablet
# 9                   tucin d syrup            akof-d syrup sugar free
# 10           ranitas 150mg tablet                ranloc 150mg tablet
# 11             torex junior syrup                     chericof syrup
# 12           proctosedyl bd cream                                NaN
# 13      tervis ds oral suspension                 bestomax dry syrup
# 14            cloud 100mcg tablet             closidin 100mcg tablet
# 15               proz 25mg tablet                prometh 25mg tablet
# 16    broxino-dx syrup sugar free                     imotus d syrup
# 17           mavifex 180mg tablet               histafree 180 tablet
# 18                  zybend tablet               albekem 400mg tablet
# 19               ralbet 2mg syrup                 asthabon 2mg syrup
# 20           nindra 0.25mg tablet                alora 0.25mg tablet
# 21         rabispan-ac capsule sr  douxrab ace 200mg/20mg capsule sr
# 22              texina 2mg tablet                 larpose 2mg tablet
# 23             cleartuss ls syrup           chericof-ls junior syrup
# 24       bronkonat 100mcg inhaler  durasal breathaler 100mcg inhaler
# 25          tidoxyl 500mg capsule              actimox 500mg capsule
# 26            stoprax 10mg tablet                hynorax 10mg tablet
# 27       omtro d 10mg/20mg tablet        prazowel d 10mg/20mg tablet
# 28           spiromax 25mg tablet              spirolact 25mg tablet
# 29        fexonix oral suspension               fext oral suspension
# 30             hedosat 10mg syrup                  livrox 10mg syrup
# 31                amlip at tablet                  amlovas-at tablet
# 32               xygrel 90 tablet                 ticastro 90 tablet
# 33              zepnap 1mg tablet                   lorel 1mg tablet
# 34                            NaN                                NaN
# 35                topnac p tablet                    arflur-p tablet
# 36            alfugress tablet pr                  emzosin tablet pr
# 37          alprazol 0.5mg tablet               texidep 0.5mg tablet
# 38              huch d3 injection          dvital 600000iu injection
# 39  cyclobid cp 25mg/300mg tablet                   camylyn-p tablet
#
#                       generic_name_5
# 0            novamox cv 625mg tablet
# 1              trulimax 500mg tablet
# 2                    broxum ls syrup
# 3               histafree 120 tablet
# 4                                NaN
# 5                 histafree-m tablet
# 6            novamox cv 625mg tablet
# 7              trulimax 500mg tablet
# 8                 zyzine 25mg tablet
# 9                    krisbro d syrup
# 10                zynol 150mg tablet
# 11                 respicure-d syrup
# 12                               NaN
# 13             amoxyril-cv dry syrup
# 14              cata-dict 0.1 tablet
# 15                  emin 25mg tablet
# 16                  brikuff-dx syrup
# 17                vilofex 180 tablet
# 18               sezole 400mg tablet
# 19           ventorlin 2mg/5ml syrup
# 20                exal 0.25mg tablet
# 21  rabewan ac 200mg/20mg capsule sr
# 22                  zelor 2mg tablet
# 23     ventiphylline ls junior syrup
# 24          asthavent 100mcg inhaler
# 25              sb mox 500mg capsule
# 26                hydrobal 10 tablet
# 27        ospicid d 10mg/20mg tablet
# 28                spironot 25 tablet
# 29  xaria kidz oral suspension mango
# 30                 anzine 10mg syrup
# 31                 amdepin-at tablet
# 32                 ticavic 90 tablet
# 33                larpose 1mg tablet
# 34                               NaN
# 35                     ark-ap tablet
# 36                  zyalfa tablet pr
# 37              zolipax 0.5mg tablet
# 38         gen-d3 600000iu injection
# 39    cyclobrex cp 25mg/300mg tablet

# %% [markdown]
# #### Transform Use Case

# %%
Use_Case_normalized = normalize_strings(Use_Case, transformations_3)

# %%
Use_Case_normalized.head(40)
# Out:
#     drug_id                                         use_case_1  \
# 0         1                  treatment of bacterial infections
# 1         2                  treatment of bacterial infections
# 2         3                      treatment of cough with mucus
# 3         4  treatment of sneezing and runny nose due to al...
# 4         5                   treatment of allergic conditions
# 5         6  treatment of sneezing and runny nose due to al...
# 6         7                  treatment of bacterial infections
# 7         8                  treatment of bacterial infections
# 8         9                               treatment of anxiety
# 9        10                             treatment of dry cough
# 10       11  treatment of gastroesophageal reflux disease (...
# 11       12                             treatment of dry cough
# 12       13                                 treatment of piles
# 13       14          treatment of resistance tuberculosis (tb)
# 14       15                                 treatment of cough
# 15       16    treatment of hypertension (high blood pressure)
# 16       17                                treatment of nausea
# 17       18                             treatment of dry cough
# 18       19  treatment of sneezing and runny nose due to al...
# 19       20                  treatment of parasitic infections
# 20       21  treatment of chronic obstructive pulmonary dis...
# 21       22                               treatment of anxiety
# 22       23                                        pain relief
# 23       24                    treatment of short term anxiety
# 24       25                      treatment of cough with mucus
# 25       26  treatment of chronic obstructive pulmonary dis...
# 26       27                  treatment of bacterial infections
# 27       28                               treatment of anxiety
# 28       29  treatment of gastroesophageal reflux disease (...
# 29       30                 hypertension (high blood pressure)
# 30       31  treatment of sneezing and runny nose due to al...
# 31       32                               treatment of anxiety
# 32       33    treatment of hypertension (high blood pressure)
# 33       34              prevention of heart attack and stroke
# 34       35                    treatment of short term anxiety
# 35       36                                  treatment of gout
# 36       37                                        pain relief
# 37       38          treatment of benign prostatic hyperplasia
# 38       39                               treatment of anxiety
# 39       40                  treatment of vitamin d deficiency
#
#                                            use_case_2
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                    treatment of allergic conditions
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   treatment of skin conditions with inflammation...
# 9                                                 NaN
# 10                  treatment of peptic ulcer disease
# 11                                                NaN
# 12                                                NaN
# 13                  treatment of bacterial infections
# 14                                                NaN
# 15                                                NaN
# 16                              treatment of vomiting
# 17                                                NaN
# 18                   treatment of allergic conditions
# 19                                                NaN
# 20                                                NaN
# 21                        treatment of panic disorder
# 22                                                NaN
# 23                      treatment of anxiety disorder
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  treatment of skin conditions with inflammation...
# 28                  treatment of peptic ulcer disease
# 29                                              edema
# 30                   treatment of allergic conditions
# 31  treatment of skin conditions with inflammation...
# 32                                                NaN
# 33                                                NaN
# 34                      treatment of anxiety disorder
# 35                          treatment of kidney stone
# 36                                                NaN
# 37                                                NaN
# 38                        treatment of panic disorder
# 39                          treatment of osteoporosis

# %% [markdown]
# #### Transform Drug Class

# %%
Drug_Class_normalized = normalize_strings(Drug_Class, transformations_4)

# %%
Drug_Class_normalized.head(40)
# Out:
#     drug_id                          chemical_class  \
# 0         1                                     NaN
# 1         2                              macrolides
# 2         3                                     NaN
# 3         4              diphenylmethane derivative
# 4         5                   pyridines derivatives
# 5         6                                     NaN
# 6         7                                     NaN
# 7         8                              macrolides
# 8         9                   piperazine derivative
# 9        10                                     NaN
# 10       11                aralkylamines derivative
# 11       12                                     NaN
# 12       13                                     NaN
# 13       14                                     NaN
# 14       15                                     NaN
# 15       16                  imidazoline derivative
# 16       17                phenothiazine derivative
# 17       18                                     NaN
# 18       19              diphenylmethane derivative
# 19       20    2-benzimidazolylcarbamic acid esters
# 20       21             benzyl alcohols derivatives
# 21       22              benzodiazepines derivative
# 22       23                                     NaN
# 23       24              benzodiazepines derivative
# 24       25                                     NaN
# 25       26             benzyl alcohols derivatives
# 26       27            aminopenicillins penicillins
# 27       28                   piperazine derivative
# 28       29                                     NaN
# 29       30             potassium sparing diuretics
# 30       31              diphenylmethane derivative
# 31       32                   piperazine derivative
# 32       33                                     NaN
# 33       34                     triazolopyrimidines
# 34       35              benzodiazepines derivative
# 35       36              carboxylic acid derivative
# 36       37                                     NaN
# 37       38                  quinazoline derivative
# 38       39              benzodiazepines derivative
# 39       40  vitamin d derivative [cholecalciferol]
#
#               therapeutic_class  \
# 0               anti infectives
# 1               anti infectives
# 2                   respiratory
# 3                   respiratory
# 4                   respiratory
# 5                   respiratory
# 6               anti infectives
# 7               anti infectives
# 8                   respiratory
# 9                   respiratory
# 10            gastro intestinal
# 11                  respiratory
# 12                        derma
# 13              anti infectives
# 14                  respiratory
# 15                      cardiac
# 16            gastro intestinal
# 17                  respiratory
# 18                  respiratory
# 19              anti infectives
# 20                  respiratory
# 21                    neuro cns
# 22              pain analgesics
# 23                  respiratory
# 24                  respiratory
# 25                  respiratory
# 26              anti infectives
# 27                  respiratory
# 28            gastro intestinal
# 29                      cardiac
# 30                  respiratory
# 31                  respiratory
# 32                      cardiac
# 33                blood related
# 34                  respiratory
# 35                      urology
# 36              pain analgesics
# 37                      urology
# 38                    neuro cns
# 39  vitamins minerals nutrients
#
#                                          action_class
# 0                                                 NaN
# 1                                          macrolides
# 2                                                 NaN
# 3              h1 antihistaminics (second generation)
# 4               h1 antihistaminics (first generation)
# 5                                                 NaN
# 6                                                 NaN
# 7                                          macrolides
# 8               h1 antihistaminics (first generation)
# 9                                                 NaN
# 10                                h2 receptor blocker
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  alpha 2-adrenoceptors agonist (central sympath...
# 16              h1 antihistaminics (first generation)
# 17                                                NaN
# 18             h1 antihistaminics (second generation)
# 19                               antiprotozoal agents
# 20                           short acting β2-agonists
# 21                                    benzodiazepines
# 22                                                NaN
# 23                                    benzodiazepines
# 24                                                NaN
# 25                           short acting β2-agonists
# 26  cell wall active agent-extended spectrum penic...
# 27              h1 antihistaminics (first generation)
# 28                                                NaN
# 29                        potassium-sparing diuretics
# 30             h1 antihistaminics (second generation)
# 31              h1 antihistaminics (first generation)
# 32                                                NaN
# 33                    p2y12 inhibitors (adp receptor)
# 34                                    benzodiazepines
# 35                              uricosuric agent-gout
# 36                                                NaN
# 37   uroselective adrenergic receptor(α1a) antagonist
# 38                                    benzodiazepines
# 39                                           vitamins

# %% [markdown]
# #### Trasnform Drug_State

# %%
def extract_generic_names(row):
    """
    Extracts generic names from generic_name columns in a DataFrame row.
    
    Args:
        row (pd.Series): A pandas Series representing a row of a DataFrame.
    
    Returns:
        str: Comma-separated string of generic names extracted from the row.
    
    Example:
        If the row has values 
        'generic_name_1': 'penciclav 500mg/125mg tablet',
        'generic_name_2': 'moxikind-cv 625 tablet', 
        the function will return 'penciclav,moxikind-cv'.
    """
    # Check if all generic_name columns are NaN
    if row.filter(like='generic_name_').isnull().all():
        return None
    
    generic_names = []
    # Iterate through the generic_name columns
    for i in range(1, 6):
        generic_name = row[f'generic_name_{i}']
        # Check if the value is a string
        if isinstance(generic_name, str):
            # Split the string and extract the first word
            generic_names.append(generic_name.split()[0])
    
    # Join the extracted generic names into a comma-separated string
    return ','.join(generic_names)

# %%
def extract_administration_method(generic_name):
    """
    This function extracts the administration method from a given generic name.
    
    Parameters:
    generic_name (str): The generic name of a medication.
    
    Returns:
    str: The extracted administration method. If no match is found, returns None.
    
    The function uses a list of common administration methods and a regular expression 
    to match the method in the generic name. The method is considered to be the first 
    word that matches the list.
    """
    
    # Check if the generic_name is a string
    if isinstance(generic_name, str):
        administration_methods = [
            'tablet', 'syrup', 'capsule', 'injection', 
            'suspension', 'iv', 'ointment', 'drop', 'cream', 
            'inhaler', 'kit', 'oral drops', 'nasal spray', 'lotion', 
            'spray', 'eye gel', 'oral gel', 'eye drop', 
            'eye/ear drops', 'dispopen', 'flextouch', 'soap',
            'oral solution', 'shampoo', 'expectorant']
        
        # Create a regex pattern to match any of the administration methods
        pattern = re.compile(r'\b(?:' + '|'.join(administration_methods) + r')\b', flags=re.IGNORECASE)
        
        # Search for the pattern in the generic_name string
        match = re.search(pattern, generic_name)
        
        if match:
            return match.group(0)
        else:
            return generic_name
    else:
        return generic_name

# %%
Drug_State.head(20)
# Out:
#     drug_id                                         use_case_1  \
# 0         1                  Treatment of Bacterial infections
# 1         2                  Treatment of Bacterial infections
# 2         3                      Treatment of Cough with mucus
# 3         4  Treatment of Sneezing and runny nose due to al...
# 4         5                   Treatment of Allergic conditions
# 5         6  Treatment of Sneezing and runny nose due to al...
# 6         7                  Treatment of Bacterial infections
# 7         8                  Treatment of Bacterial infections
# 8         9                               Treatment of Anxiety
# 9        10                             Treatment of Dry cough
# 10       11  Treatment of Gastroesophageal reflux disease (...
# 11       12                             Treatment of Dry cough
# 12       13                                 Treatment of Piles
# 13       14          Treatment of Resistance Tuberculosis (TB)
# 14       15                                 Treatment of Cough
# 15       16    Treatment of Hypertension (high blood pressure)
# 16       17                                Treatment of Nausea
# 17       18                             Treatment of Dry cough
# 18       19  Treatment of Sneezing and runny nose due to al...
# 19       20                  Treatment of Parasitic infections
#
#                       generic_name_1               generic_name_2  \
# 0     Penciclav 500 mg/125 mg Tablet       Moxikind-CV 625 Tablet
# 1            Zithrocare 500mg Tablet              Azax 500 Tablet
# 2                    Solvin LS Syrup            Ambrodil-LX Syrup
# 3                       Lcfex Tablet          Etofex 120mg Tablet
# 4                 Eralet 25mg Tablet                          NaN
# 5                 Emlukast-FX Tablet            LCFEX-Mont Tablet
# 6     Penciclav 500 mg/125 mg Tablet       Moxikind-CV 625 Tablet
# 7            Zithrocare 500mg Tablet              Azax 500 Tablet
# 8                HD Zine 25mg Tablet              Hyzox 25 Tablet
# 9                    Arnikof D Syrup             Cofsolve-D Syrup
# 10                Zinemac 150 Tablet         Monoloc 150mg Tablet
# 11                Alkof Junior Syrup            Respicure-D Syrup
# 12                     Pilo GO Cream              PileClear Cream
# 13          Goldclav Oral Suspension           Moxiclip Dry Syrup
# 14                               NaN                          NaN
# 15            Albamine 100mcg Tablet          Arkapres 100 Tablet
# 16                  Propazine Tablet          Progene 25mg Tablet
# 17  Wytuss-DMR Syrup Mint Sugar Free  Dcrocof-DX Syrup Sugar Free
# 18                  Lcfex 180 Tablet         Fexofen 180mg Tablet
# 19               Olworm 400mg Tablet                Zeebee Tablet
#
#                  generic_name_3           generic_name_4  \
# 0       Moxiforce-CV 625 Tablet       Fightox 625 Tablet
# 1               Zady 500 Tablet    Cazithro 500mg Tablet
# 2             Zerotuss XP Syrup           Capex LS Syrup
# 3          Nexofex 120mg Tablet      Fexise 120mg Tablet
# 4                           NaN                      NaN
# 5       Fixar 10mg/120mg Tablet       Histakind-M Tablet
# 6       Moxiforce-CV 625 Tablet       Fightox 625 Tablet
# 7               Zady 500 Tablet    Cazithro 500mg Tablet
# 8             Hizet 25mg Tablet        Hydil 25mg Tablet
# 9                 Tucin D Syrup  Akof-D Syrup Sugar Free
# 10         Ranitas 150mg Tablet      Ranloc 150mg Tablet
# 11           Torex Junior Syrup           Chericof Syrup
# 12         Proctosedyl BD Cream                      NaN
# 13    Tervis DS Oral Suspension       Bestomax Dry Syrup
# 14                          NaN                      NaN
# 15          Cloud 100mcg Tablet   Closidin 100mcg Tablet
# 16             Proz 25mg Tablet      Prometh 25mg Tablet
# 17  Broxino-DX Syrup Sugar Free           Imotus D Syrup
# 18         Mavifex 180mg Tablet     Histafree 180 Tablet
# 19                Zybend Tablet     Albekem 400mg Tablet
#
#              generic_name_5  therapeutic_class
# 0   Novamox CV 625mg Tablet    ANTI INFECTIVES
# 1     Trulimax 500mg Tablet    ANTI INFECTIVES
# 2           Broxum LS Syrup        RESPIRATORY
# 3      Histafree 120 Tablet        RESPIRATORY
# 4                       NaN        RESPIRATORY
# 5        Histafree-M Tablet        RESPIRATORY
# 6   Novamox CV 625mg Tablet    ANTI INFECTIVES
# 7     Trulimax 500mg Tablet    ANTI INFECTIVES
# 8        Zyzine 25mg Tablet        RESPIRATORY
# 9           Krisbro D Syrup        RESPIRATORY
# 10       Zynol 150mg Tablet  GASTRO INTESTINAL
# 11        Respicure-D Syrup        RESPIRATORY
# 12                      NaN              DERMA
# 13    Amoxyril-CV Dry Syrup    ANTI INFECTIVES
# 14                      NaN        RESPIRATORY
# 15     Cata-Dict 0.1 Tablet            CARDIAC
# 16         Emin 25mg Tablet  GASTRO INTESTINAL
# 17         Brikuff-DX Syrup        RESPIRATORY
# 18       Vilofex 180 Tablet        RESPIRATORY
# 19      Sezole 400mg Tablet    ANTI INFECTIVES

# %%
Drug_State_normalized = normalize_strings(Drug_State, transformations_5)

# %%
# Create the new column 'generic_profile'
Drug_State_normalized['generic_profile'] = Drug_State_normalized.apply(extract_generic_names, axis=1)

# %%
# Apply the function to the generic_name_1 column
Drug_State_normalized['administration_method'] = Drug_State_normalized['generic_name_1'].apply(extract_administration_method)

# %%
Drug_State_normalized.head(20)
# Out:
#     drug_id                                         use_case_1  \
# 0         1                  treatment of bacterial infections
# 1         2                  treatment of bacterial infections
# 2         3                      treatment of cough with mucus
# 3         4  treatment of sneezing and runny nose due to al...
# 4         5                   treatment of allergic conditions
# 5         6  treatment of sneezing and runny nose due to al...
# 6         7                  treatment of bacterial infections
# 7         8                  treatment of bacterial infections
# 8         9                               treatment of anxiety
# 9        10                             treatment of dry cough
# 10       11  treatment of gastroesophageal reflux disease (...
# 11       12                             treatment of dry cough
# 12       13                                 treatment of piles
# 13       14          treatment of resistance tuberculosis (tb)
# 14       15                                 treatment of cough
# 15       16    treatment of hypertension (high blood pressure)
# 16       17                                treatment of nausea
# 17       18                             treatment of dry cough
# 18       19  treatment of sneezing and runny nose due to al...
# 19       20                  treatment of parasitic infections
#
#                       generic_name_1               generic_name_2  \
# 0       penciclav 500mg/125mg tablet       moxikind-cv 625 tablet
# 1            zithrocare 500mg tablet              azax 500 tablet
# 2                    solvin ls syrup            ambrodil-lx syrup
# 3                       lcfex tablet          etofex 120mg tablet
# 4                 eralet 25mg tablet                          NaN
# 5                 emlukast-fx tablet            lcfex-mont tablet
# 6       penciclav 500mg/125mg tablet       moxikind-cv 625 tablet
# 7            zithrocare 500mg tablet              azax 500 tablet
# 8                hd zine 25mg tablet              hyzox 25 tablet
# 9                    arnikof d syrup             cofsolve-d syrup
# 10                zinemac 150 tablet         monoloc 150mg tablet
# 11                alkof junior syrup            respicure-d syrup
# 12                     pilo go cream              pileclear cream
# 13          goldclav oral suspension           moxiclip dry syrup
# 14                               NaN                          NaN
# 15            albamine 100mcg tablet          arkapres 100 tablet
# 16                  propazine tablet          progene 25mg tablet
# 17  wytuss-dmr syrup mint sugar free  dcrocof-dx syrup sugar free
# 18                  lcfex 180 tablet         fexofen 180mg tablet
# 19               olworm 400mg tablet                zeebee tablet
#
#                  generic_name_3           generic_name_4  \
# 0       moxiforce-cv 625 tablet       fightox 625 tablet
# 1               zady 500 tablet    cazithro 500mg tablet
# 2             zerotuss xp syrup           capex ls syrup
# 3          nexofex 120mg tablet      fexise 120mg tablet
# 4                           NaN                      NaN
# 5       fixar 10mg/120mg tablet       histakind-m tablet
# 6       moxiforce-cv 625 tablet       fightox 625 tablet
# 7               zady 500 tablet    cazithro 500mg tablet
# 8             hizet 25mg tablet        hydil 25mg tablet
# 9                 tucin d syrup  akof-d syrup sugar free
# 10         ranitas 150mg tablet      ranloc 150mg tablet
# 11           torex junior syrup           chericof syrup
# 12         proctosedyl bd cream                      NaN
# 13    tervis ds oral suspension       bestomax dry syrup
# 14                          NaN                      NaN
# 15          cloud 100mcg tablet   closidin 100mcg tablet
# 16             proz 25mg tablet      prometh 25mg tablet
# 17  broxino-dx syrup sugar free           imotus d syrup
# 18         mavifex 180mg tablet     histafree 180 tablet
# 19                zybend tablet     albekem 400mg tablet
#
#              generic_name_5  therapeutic_class  \
# 0   novamox cv 625mg tablet    anti infectives
# 1     trulimax 500mg tablet    anti infectives
# 2           broxum ls syrup        respiratory
# 3      histafree 120 tablet        respiratory
# 4                       NaN        respiratory
# 5        histafree-m tablet        respiratory
# 6   novamox cv 625mg tablet    anti infectives
# 7     trulimax 500mg tablet    anti infectives
# 8        zyzine 25mg tablet        respiratory
# 9           krisbro d syrup        respiratory
# 10       zynol 150mg tablet  gastro intestinal
# 11        respicure-d syrup        respiratory
# 12                      NaN              derma
# 13    amoxyril-cv dry syrup    anti infectives
# 14                      NaN        respiratory
# 15     cata-dict 0.1 tablet            cardiac
# 16         emin 25mg tablet  gastro intestinal
# 17         brikuff-dx syrup        respiratory
# 18       vilofex 180 tablet        respiratory
# 19      sezole 400mg tablet    anti infectives
#
#                                       generic_profile administration_method
# 0   penciclav,moxikind-cv,moxiforce-cv,fightox,nov...                tablet
# 1              zithrocare,azax,zady,cazithro,trulimax                tablet
# 2            solvin,ambrodil-lx,zerotuss,capex,broxum                 syrup
# 3               lcfex,etofex,nexofex,fexise,histafree                tablet
# 4                                              eralet                tablet
# 5   emlukast-fx,lcfex-mont,fixar,histakind-m,hista...                tablet
# 6   penciclav,moxikind-cv,moxiforce-cv,fightox,nov...                tablet
# 7              zithrocare,azax,zady,cazithro,trulimax                tablet
# 8                         hd,hyzox,hizet,hydil,zyzine                tablet
# 9             arnikof,cofsolve-d,tucin,akof-d,krisbro                 syrup
# 10               zinemac,monoloc,ranitas,ranloc,zynol                tablet
# 11       alkof,respicure-d,torex,chericof,respicure-d                 syrup
# 12                         pilo,pileclear,proctosedyl                 cream
# 13      goldclav,moxiclip,tervis,bestomax,amoxyril-cv            suspension
# 14                                               None                   NaN
# 15         albamine,arkapres,cloud,closidin,cata-dict                tablet
# 16                propazine,progene,proz,prometh,emin                tablet
# 17  wytuss-dmr,dcrocof-dx,broxino-dx,imotus,brikuf...                 syrup
# 18            lcfex,fexofen,mavifex,histafree,vilofex                tablet
# 19                olworm,zeebee,zybend,albekem,sezole                tablet

# %%
# Drop the generic_name columns
columns_to_drop = ['generic_name_1', 'generic_name_2', 
                'generic_name_3', 'generic_name_4', 'generic_name_5']

Drug_State_normalized.drop(columns=columns_to_drop, inplace=True)
Drug_State_normalized.reset_index(drop=True, inplace=True)

# %%
cols = {
    'use_case_1': 'case_definition',
    'therapeutic_class': 'therapeutic_type'
}

Drug_State_normalized.rename(columns=cols, inplace=True)

# %%
Drug_State_normalized.head(20)
# Out:
#     drug_id                                    case_definition  \
# 0         1                  treatment of bacterial infections
# 1         2                  treatment of bacterial infections
# 2         3                      treatment of cough with mucus
# 3         4  treatment of sneezing and runny nose due to al...
# 4         5                   treatment of allergic conditions
# 5         6  treatment of sneezing and runny nose due to al...
# 6         7                  treatment of bacterial infections
# 7         8                  treatment of bacterial infections
# 8         9                               treatment of anxiety
# 9        10                             treatment of dry cough
# 10       11  treatment of gastroesophageal reflux disease (...
# 11       12                             treatment of dry cough
# 12       13                                 treatment of piles
# 13       14          treatment of resistance tuberculosis (tb)
# 14       15                                 treatment of cough
# 15       16    treatment of hypertension (high blood pressure)
# 16       17                                treatment of nausea
# 17       18                             treatment of dry cough
# 18       19  treatment of sneezing and runny nose due to al...
# 19       20                  treatment of parasitic infections
#
#      therapeutic_type                                    generic_profile  \
# 0     anti infectives  penciclav,moxikind-cv,moxiforce-cv,fightox,nov...
# 1     anti infectives             zithrocare,azax,zady,cazithro,trulimax
# 2         respiratory           solvin,ambrodil-lx,zerotuss,capex,broxum
# 3         respiratory              lcfex,etofex,nexofex,fexise,histafree
# 4         respiratory                                             eralet
# 5         respiratory  emlukast-fx,lcfex-mont,fixar,histakind-m,hista...
# 6     anti infectives  penciclav,moxikind-cv,moxiforce-cv,fightox,nov...
# 7     anti infectives             zithrocare,azax,zady,cazithro,trulimax
# 8         respiratory                        hd,hyzox,hizet,hydil,zyzine
# 9         respiratory            arnikof,cofsolve-d,tucin,akof-d,krisbro
# 10  gastro intestinal               zinemac,monoloc,ranitas,ranloc,zynol
# 11        respiratory       alkof,respicure-d,torex,chericof,respicure-d
# 12              derma                         pilo,pileclear,proctosedyl
# 13    anti infectives      goldclav,moxiclip,tervis,bestomax,amoxyril-cv
# 14        respiratory                                               None
# 15            cardiac         albamine,arkapres,cloud,closidin,cata-dict
# 16  gastro intestinal                propazine,progene,proz,prometh,emin
# 17        respiratory  wytuss-dmr,dcrocof-dx,broxino-dx,imotus,brikuf...
# 18        respiratory            lcfex,fexofen,mavifex,histafree,vilofex
# 19    anti infectives                olworm,zeebee,zybend,albekem,sezole
#
#    administration_method
# 0                 tablet
# 1                 tablet
# 2                  syrup
# 3                 tablet
# 4                 tablet
# 5                 tablet
# 6                 tablet
# 7                 tablet
# 8                 tablet
# 9                  syrup
# 10                tablet
# 11                 syrup
# 12                 cream
# 13            suspension
# 14                   NaN
# 15                tablet
# 16                tablet
# 17                 syrup
# 18                tablet
# 19                tablet

# %% [markdown]
# #### Transform Side Effects

# %%
Side_Effects.head(20)
# Out:
#     drug_id                                      side_effect_1  \
# 0         1                                           Vomiting
# 1         2                                           Vomiting
# 2         3                                             Nausea
# 3         4                                           Headache
# 4         5                                         Sleepiness
# 5         6                                             Nausea
# 6         7                                           Vomiting
# 7         8                                           Vomiting
# 8         9                                           Sedation
# 9        10                                             Nausea
# 10       11                                           Headache
# 11       12                                             Nausea
# 12       13  Application site reactions (burning, irritatio...
# 13       14                                             Nausea
# 14       15                                           Headache
# 15       16                                          Dizziness
# 16       17  Unusual production of breast milk in women and...
# 17       18                                             Nausea
# 18       19                                           Headache
# 19       20                                           Vomiting
#
#        side_effect_2                 side_effect_3  side_effect_4  \
# 0             Nausea                      Diarrhea            NaN
# 1             Nausea                Abdominal pain       Diarrhea
# 2           Vomiting                      Diarrhea  Upset stomach
# 3         Drowsiness                     Dizziness         Nausea
# 4   Dryness in mouth                           NaN            NaN
# 5           Diarrhea                      Vomiting      Skin rash
# 6             Nausea                      Diarrhea            NaN
# 7             Nausea                Abdominal pain       Diarrhea
# 8             Nausea                      Vomiting  Upset stomach
# 9           Vomiting              Loss of appetite       Headache
# 10          Diarrhea  Gastrointestinal disturbance            NaN
# 11          Vomiting              Loss of appetite       Headache
# 12               NaN                           NaN            NaN
# 13          Vomiting                Abdominal pain       Diarrhea
# 14      Palpitations                 Upset stomach        Tremors
# 15  Dryness in mouth                      Headache         Nausea
# 16               NaN                           NaN            NaN
# 17          Vomiting              Loss of appetite       Headache
# 18        Drowsiness                     Dizziness         Nausea
# 19         Dizziness       Increased liver enzymes         Nausea
#
#         side_effect_5
# 0                 NaN
# 1                 NaN
# 2        Stomach pain
# 3                 NaN
# 4                 NaN
# 5   Flu-like symptoms
# 6                 NaN
# 7                 NaN
# 8        Constipation
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13            Allergy
# 14       Muscle cramp
# 15            Fatigue
# 16                NaN
# 17                NaN
# 18                NaN
# 19   Loss of appetite

# %%
Side_Effects_normalized = normalize_strings(Side_Effects, transformations_6)

# %%
Side_Effects_normalized.head(20)
# Out:
#     drug_id                                      side_effect_1  \
# 0         1                                           vomiting
# 1         2                                           vomiting
# 2         3                                             nausea
# 3         4                                           headache
# 4         5                                         sleepiness
# 5         6                                             nausea
# 6         7                                           vomiting
# 7         8                                           vomiting
# 8         9                                           sedation
# 9        10                                             nausea
# 10       11                                           headache
# 11       12                                             nausea
# 12       13  application site reactions (burning, irritatio...
# 13       14                                             nausea
# 14       15                                           headache
# 15       16                                          dizziness
# 16       17  unusual production of breast milk in women and...
# 17       18                                             nausea
# 18       19                                           headache
# 19       20                                           vomiting
#
#        side_effect_2                 side_effect_3  side_effect_4  \
# 0             nausea                      diarrhea            NaN
# 1             nausea                abdominal pain       diarrhea
# 2           vomiting                      diarrhea  upset stomach
# 3         drowsiness                     dizziness         nausea
# 4   dryness in mouth                           NaN            NaN
# 5           diarrhea                      vomiting      skin rash
# 6             nausea                      diarrhea            NaN
# 7             nausea                abdominal pain       diarrhea
# 8             nausea                      vomiting  upset stomach
# 9           vomiting              loss of appetite       headache
# 10          diarrhea  gastrointestinal disturbance            NaN
# 11          vomiting              loss of appetite       headache
# 12               NaN                           NaN            NaN
# 13          vomiting                abdominal pain       diarrhea
# 14      palpitations                 upset stomach        tremors
# 15  dryness in mouth                      headache         nausea
# 16               NaN                           NaN            NaN
# 17          vomiting              loss of appetite       headache
# 18        drowsiness                     dizziness         nausea
# 19         dizziness       increased liver enzymes         nausea
#
#         side_effect_5
# 0                 NaN
# 1                 NaN
# 2        stomach pain
# 3                 NaN
# 4                 NaN
# 5   flu-like symptoms
# 6                 NaN
# 7                 NaN
# 8        constipation
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13            allergy
# 14       muscle cramp
# 15            fatigue
# 16                NaN
# 17                NaN
# 18                NaN
# 19   loss of appetite
